# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: customer activity (yes/no)

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [markdown]
# Answer:  (based on age, gender,location and profession)

# %% [markdown]
# #### 3. What timeframe is this data relevent for?

# %% [markdown]
# Answer: 4 months in 2015 (Jan - April 2015)

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: Demografic information + How often they use the service determines whether they will convert to paying customers

# %% [markdown]
# ## Let's get started with our dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
from IPython.display import display
import numpy as np
import pylab

orig_data = pd.read_csv('admissions.csv')

# %%
orig_data.head(10)
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0
# 5      1  760.0  3.00       2.0
# 6      1  560.0  2.98       1.0
# 7      0  400.0  3.08       2.0
# 8      1  540.0  3.39       3.0
# 9      0  700.0  3.92       2.0

# %%
orig_data.var()
# Out:
# admit           0.217237
# gre         13369.953040
# gpa             0.144879
# prestige        0.893654
# dtype: float64

# %%
orig_data.cov()
# Out:
#              admit           gre        gpa   prestige
# admit     0.217237      9.871271   0.031191  -0.106189
# gre       9.871271  13369.953040  16.824761 -13.648068
# gpa       0.031191     16.824761   0.144879  -0.021260
# prestige -0.106189    -13.648068  -0.021260   0.893654

# %%
orig_data.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.182919  0.175952 -0.241355
# gre       0.182919  1.000000  0.382408 -0.124533
# gpa       0.175952  0.382408  1.000000 -0.059031
# prestige -0.241355 -0.124533 -0.059031  1.000000

# %%
# orig_data.plot()
orig_data['gre'].plot()
plt.show()

# %%
orig_data['gpa'].plot()
plt.show()

# %%
# orig_data['admit'].plot()
orig_data.admit.value_counts()
# Out:
# 0    273
# 1    127
# Name: admit, dtype: int64

# %%
orig_data.prestige.value_counts()
# Out:
# 2.0    150
# 3.0    121
# 4.0     67
# 1.0     61
# Name: prestige, dtype: int64

# %%
mask_1 = orig_data['admit'] == 1
orig_data[mask_1]['gre'].plot()
plt.show()

# %%
mask_1 = orig_data['admit'] == 1
orig_data[mask_1]['gpa'].plot()
plt.show()

# %%
mask_1 = orig_data['admit'] == 1
orig_data[mask_1]['gpa'].plot()

# %%
pd.scatter_matrix(orig_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %% [markdown]
# #### 1. Create a data dictionary

# %% [markdown]
# Answer:
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Admit | 0 = No 1 = Yes  | categorical/binary
# GRE Score | 0-700 | continuous
# GPA | 0.01-4.0 | continuous
# Prestige | 1-4 | discrete

# %% [markdown]
# We would like to explore the association between X and Y

# %% [markdown]
# #### 2. What is the outcome?

# %% [markdown]
# Answer: Y = prestige, X= GRE or GPA

# %% [markdown]
# #### 3. What are the predictors/covariates?

# %% [markdown]
# Answer: GRE score and GPA

# %% [markdown]
# #### 4. What timeframe is this data relevent for?

# %% [markdown]
# Answer: from Jan - April 2015

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: the higher the score and gpa and Higher the Prestige of Admission

# %% [markdown]
#     Using the above information, write a well-formed problem statement.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Exploratory Analysis Plan

# %% [markdown]
# Using the lab from a class as a guide, create an exploratory analysis plan.

# %% [markdown]
# #### 1. What are the goals of the exploratory analysis?

# %% [markdown]
# Answer: to produce reliable and reproducible results

# %% [markdown]
# #### 2a. What are the assumptions of the distribution of data?

# %% [markdown]
# Answer: 1. That it is truthful, 2. That is is available (and will continue to be) 3. it correlates with one another

# %% [markdown]
# #### 2b. How will determine the distribution of your data?

# %% [markdown]
# Answer: parsing the data

# %% [markdown]
# #### 3a. How might outliers impact your analysis?

# %% [markdown]
# Answer: it may scew the findings negatively or positively from the core data

# %% [markdown]
# #### 3b. How will you test for outliers?

# %% [markdown]
# Answer: logorithm

# %% [markdown]
# #### 4a. What is colinearity?

# %% [markdown]
# Answer: having two different variable placed with one another in a liner fashion

# %% [markdown]
# #### 4b. How will you test for colinearity?

# %% [markdown]
# Answer: .corr() in pd

# %% [markdown]
# #### 5. What is your exploratory analysis plan?
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.

# %% [markdown]
# Answer: after pasring, mining and scaling the data. I would then be able to clearly see and test patterns to give an hypothesis. After testing the correlations of the variables through the linear regression model, i could then begin to undrestand the relationship of the data. I can begin to ask questions. (Where? Why? How?). Form a hopthesis, then begin to ask SMART questions.

# %% [markdown]
# ## Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model
